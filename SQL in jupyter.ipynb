# %% [markdown]
# ##  SQL, in jupyter
#
#
# ### Turki Aljrees , 2020

# %% [markdown]
# ----

# %%
sqldf('SELECT * FROM LungCapData')
# Out:
#     LungCap Age Height Smoke Gender Caesarean
# 1    6.475   6  62.1   no    male   no
# 2   10.125  18  74.7   yes   female no
# 3    9.550  16  69.7   no    female yes
# 4   11.125  14  71.0   no    male   no
# 5    4.800   5  56.9   no    male   no
# 6    6.225  11  58.7   no    female no
# 7    4.950   8  63.3   no    male   yes
# 8    7.325  11  70.4   no    male   no
# 9    8.875  15  70.5   no    male   no
# 10   6.800  11  59.2   no    male   no
# 11  11.500  19  76.4   no    male   yes
# 12  10.925  17  71.7   no    male   no
# 13   6.525  12  57.5   no    male   no
# 14   6.000  10  61.1   no    female no
# 15   7.825  10  61.2   no    male   no
# 16   9.525  13  63.5   no    male   yes
# 17   7.875  15  59.2   no    male   no
# 18   5.050   8  56.1   no    male   no
# 19   7.025  11  61.2   yes   female no
# 20   9.525  14  70.6   no    female no
# 21   3.975   6  57.3   no    male   no
# 22   5.325   8  59.7   no    female no
# 23  10.025  16  72.4   no    male   no
# ...

# %%
sqldf('SELECT * FROM LungCapData limit 6')
# Out:
#   LungCap Age Height Smoke Gender Caesarean
# 1  6.475   6  62.1   no    male   no
# 2 10.125  18  74.7   yes   female no
# 3  9.550  16  69.7   no    female yes
# 4 11.125  14  71.0   no    male   no
# 5  4.800   5  56.9   no    male   no
# 6  6.225  11  58.7   no    female no

# %%
#query contanitmnet 

Query1 <- sqldf('SELECT * FROM LungCapData WHERE Gender = "female"')

# %%
sqldf('SELECT * FROM Query1 limit 6')
# Out:
#   LungCap Age Height Smoke Gender Caesarean
# 1 10.125  18  74.7   yes   female no
# 2  9.550  16  69.7   no    female yes
# 3  6.225  11  58.7   no    female no
# 4  6.000  10  61.1   no    female no
# 5  7.025  11  61.2   yes   female no
# 6  9.525  14  70.6   no    female no

# %%
Query2 <- sqldf('SELECT * FROM Query1 WHERE Smoke = "no"')

# %%
sqldf('SELECT * FROM Query2 limit 6')
# Out:
#   LungCap Age Height Smoke Gender Caesarean
# 1 9.550   16  69.7   no    female yes
# 2 6.225   11  58.7   no    female no
# 3 6.000   10  61.1   no    female no
# 4 9.525   14  70.6   no    female no
# 5 5.325    8  59.7   no    female no
# 6 9.375   11  65.7   no    female no
